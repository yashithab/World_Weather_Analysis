# %%
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 754

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | kapaa
# Processing Record 2 of the Set 1 | mayna
# Processing Record 3 of the Set 1 | xucheng
# Processing Record 4 of the Set 1 | bratsk
# Processing Record 5 of the Set 1 | kodiak
# Processing Record 6 of the Set 1 | terra santa
# Processing Record 7 of the Set 1 | ust-bolsheretsk
# Processing Record 8 of the Set 1 | beringovskiy
# Processing Record 9 of the Set 1 | victoria
# Processing Record 10 of the Set 1 | puerto ayora
# Processing Record 11 of the Set 1 | nikolskoye
# Processing Record 12 of the Set 1 | cherskiy
# Processing Record 13 of the Set 1 | bredasdorp
# Processing Record 14 of the Set 1 | uzunovo
# Processing Record 15 of the Set 1 | coihaique
# Processing Record 16 of the Set 1 | jamestown
# Processing Record 17 of the Set 1 | albany
# Processing Record 18 of the Set 1 | toliary
# City not found. Skipping...
# Processing Record 19 of the Set 1 | viransehir
# Processing Record 20 of the Set 1 | mahebourg
# Processing Record 21 of the Set 1 | canutama
# Processing Record 22 of the Set 1 | omachi
# Processing Record 23 of the Set 1 | saint-philippe
# Processing Record 24 of the Set 1 | khatanga
# Processing Record 25 of the Set 1 | ponta delgada
# Processing Record 26 of the Set 1 | maymanak
# City not found. Skipping...
# Processing Record 27 of the Set 1 | ocos
# Processing Record 28 of the Set 1 | coahuayana
# Processing Record 29 of the Set 1 | erdenet
# Processing Record 30 of the Set 1 | gadoros
# Processing Record 31 of the Set 1 | bluff
# Processing Record 32 of the Set 1 | korla
# Processing Record 33 of the Set 1 | yellowknife
# Processing Record 34 of the Set 1 | hithadhoo
# Processing Record 35 of the Set 1 | waingapu
# Processing Record 36 of the Set 1 | marawi
# Processing Record 37 of the Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 38 of the Set 1 | chuy
# Processing Record 39 of the Set 1 | rikitea
# Processing Record 40 of the Set 1 | alyangula
# Processing Record 41 of the Set 1 | ushuaia
# Processing Record 42 of the Set 1 | rio gallegos
# Processing Record 43 of the Set 1 | lebu
# Processing Record 44 of the Set 1 | chapais
# Processing Record 45 of the Set 1 | troitskoye
# Processing Record 46 of the Set 1 | les cayes
# Processing Record 47 of the Set 1 | ribeira grande
# Processing Record 48 of the Set 1 | bubaque
# Processing Record 49 of the Set 1 | punta arenas
# Processing Record 50 of the Set 1 | mys shmidta
# Processing Record 1 of the Set 2 | dikson
# Processing Record 2 of the Set 2 | hatillo
# Processing Record 3 of the Set 2 | cap malheureux
# Processing Record 4 of the Set 2 | barrow
# Processing Record 5 of the Set 2 | aklavik
# Processing Record 6 of the Set 2 | rungata
# City not found. Skipping...
# Processing Record 7 of the Set 2 | thompson
# Processing Record 8 of the Set 2 | cape town
# Processing Record 9 of the Set 2 | smithers
# Processing Record 10 of the Set 2 | homer
# Processing Record 11 of the Set 2 | castro
# Processing Record 12 of the Set 2 | bilma
# Processing Record 13 of the Set 2 | hobart
# Processing Record 14 of the Set 2 | saskylakh
# Processing Record 15 of the Set 2 | teahupoo
# Processing Record 16 of the Set 2 | new norfolk
# Processing Record 17 of the Set 2 | ginda
# Processing Record 18 of the Set 2 | esperance
# Processing Record 19 of the Set 2 | kaitangata
# Processing Record 20 of the Set 2 | hilo
# Processing Record 21 of the Set 2 | wanning
# Processing Record 22 of the Set 2 | yaan
# Processing Record 23 of the Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of the Set 2 | amderma
# Processing Record 25 of the Set 2 | dipkarpaz
# City not found. Skipping...
# Processing Record 26 of the Set 2 | yulara
# Processing Record 27 of the Set 2 | chlorakas
# City not found. Skipping...
# Processing Record 28 of the Set 2 | arraial do cabo
# Processing Record 29 of the Set 2 | clyde river
# Processing Record 30 of the Set 2 | severo-kurilsk
# Processing Record 31 of the Set 2 | bosaso
# Processing Record 32 of the Set 2 | brandenburg
# Processing Record 33 of the Set 2 | kavieng
# Processing Record 34 of the Set 2 | lagoa
# Processing Record 35 of the Set 2 | atuona
# Processing Record 36 of the Set 2 | husavik
# Processing Record 37 of the Set 2 | pevek
# Processing Record 38 of the Set 2 | busselton
# Processing Record 39 of the Set 2 | taltal
# Processing Record 40 of the Set 2 | mar del plata
# Processing Record 41 of the Set 2 | saryozek
# Processing Record 42 of the Set 2 | hobyo
# Processing Record 43 of the Set 2 | salalah
# Processing Record 44 of the Set 2 | portland
# Processing Record 45 of the Set 2 | talnakh
# Processing Record 46 of the Set 2 | fortuna
# Processing Record 47 of the Set 2 | imbituba
# Processing Record 48 of the Set 2 | palabuhanratu
# Processing Record 49 of the Set 2 | alekseyevsk
# Processing Record 50 of the Set 2 | lorengau
# Processing Record 1 of the Set 3 | peniche
# Processing Record 2 of the Set 3 | luwuk
# Processing Record 3 of the Set 3 | tuktoyaktuk
# Processing Record 4 of the Set 3 | hamilton
# Processing Record 5 of the Set 3 | vaini
# Processing Record 6 of the Set 3 | mogapi
# Processing Record 7 of the Set 3 | manokwari
# Processing Record 8 of the Set 3 | barabinsk
# Processing Record 9 of the Set 3 | tokur
# Processing Record 10 of the Set 3 | sur
# Processing Record 11 of the Set 3 | mana
# Processing Record 12 of the Set 3 | volosovo
# Processing Record 13 of the Set 3 | the valley
# Processing Record 14 of the Set 3 | port alfred
# Processing Record 15 of the Set 3 | kloulklubed
# Processing Record 16 of the Set 3 | bolila
# Processing Record 17 of the Set 3 | norsup
# Processing Record 18 of the Set 3 | geraldton
# Processing Record 19 of the Set 3 | sakakah
# Processing Record 20 of the Set 3 | attawapiskat
# Processing Record 21 of the Set 3 | kavaratti
# Processing Record 22 of the Set 3 | prince rupert
# Processing Record 23 of the Set 3 | isabela
# Processing Record 24 of the Set 3 | hasaki
# Processing Record 25 of the Set 3 | butaritari
# City not found. Skipping...
# Processing Record 26 of the Set 3 | sulangan
# Processing Record 27 of the Set 3 | yumen
# Processing Record 28 of the Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of the Set 3 | iskateley
# Processing Record 30 of the Set 3 | ust-nera
# Processing Record 31 of the Set 3 | caravelas
# Processing Record 32 of the Set 3 | acarau
# Processing Record 33 of the Set 3 | leningradskiy
# Processing Record 34 of the Set 3 | shimoda
# Processing Record 35 of the Set 3 | vagay
# Processing Record 36 of the Set 3 | paraiso
# Processing Record 37 of the Set 3 | statesboro
# Processing Record 38 of the Set 3 | cidreira
# Processing Record 39 of the Set 3 | laguna
# Processing Record 40 of the Set 3 | biak
# Processing Record 41 of the Set 3 | luderitz
# Processing Record 42 of the Set 3 | san pedro
# Processing Record 43 of the Set 3 | saint-pierre
# Processing Record 44 of the Set 3 | lumby
# Processing Record 45 of the Set 3 | walvis bay
# Processing Record 46 of the Set 3 | san vicente
# Processing Record 47 of the Set 3 | paita
# Processing Record 48 of the Set 3 | jomalig
# Processing Record 49 of the Set 3 | port blair
# Processing Record 50 of the Set 3 | isangel
# Processing Record 1 of the Set 4 | novi pazar
# Processing Record 2 of the Set 4 | norman wells
# Processing Record 3 of the Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of the Set 4 | ketrzyn
# Processing Record 5 of the Set 4 | haines junction
# Processing Record 6 of the Set 4 | krasnyye tkachi
# Processing Record 7 of the Set 4 | bambanglipuro
# Processing Record 8 of the Set 4 | vwawa
# Processing Record 9 of the Set 4 | manavalakurichi
# Processing Record 10 of the Set 4 | torbay
# Processing Record 11 of the Set 4 | tamiahua
# Processing Record 12 of the Set 4 | rovaniemi
# Processing Record 13 of the Set 4 | velyka lepetykha
# Processing Record 14 of the Set 4 | cockburn town
# Processing Record 15 of the Set 4 | alofi
# Processing Record 16 of the Set 4 | east london
# Processing Record 17 of the Set 4 | temple
# Processing Record 18 of the Set 4 | lasa
# Processing Record 19 of the Set 4 | derzhavinsk
# Processing Record 20 of the Set 4 | thinadhoo
# Processing Record 21 of the Set 4 | portmore
# Processing Record 22 of the Set 4 | raudeberg
# Processing Record 23 of the Set 4 | paris
# Processing Record 24 of the Set 4 | mahanoro
# City not found. Skipping...
# Processing Record 25 of the Set 4 | belushya guba
# Processing Record 26 of the Set 4 | windsor
# Processing Record 27 of the Set 4 | vila velha
# Processing Record 28 of the Set 4 | amapa
# Processing Record 29 of the Set 4 | iqaluit
# Processing Record 30 of the Set 4 | pakokku
# Processing Record 31 of the Set 4 | faya
# Processing Record 32 of the Set 4 | natalio
# Processing Record 33 of the Set 4 | bathsheba
# Processing Record 34 of the Set 4 | grand river south east
# Processing Record 35 of the Set 4 | brae
# Processing Record 36 of the Set 4 | neuquen
# Processing Record 37 of the Set 4 | ahipara
# Processing Record 38 of the Set 4 | beidao
# Processing Record 39 of the Set 4 | meulaboh
# Processing Record 40 of the Set 4 | mataura
# Processing Record 41 of the Set 4 | igarka
# Processing Record 42 of the Set 4 | sentyabrskiy
# Processing Record 43 of the Set 4 | padang
# Processing Record 44 of the Set 4 | san quintin
# Processing Record 45 of the Set 4 | borovoy
# Processing Record 46 of the Set 4 | moron
# Processing Record 47 of the Set 4 | pisco
# Processing Record 48 of the Set 4 | haicheng
# Processing Record 49 of the Set 4 | nome
# Processing Record 50 of the Set 4 | faanui
# Processing Record 1 of the Set 5 | poum
# Processing Record 2 of the Set 5 | ancud
# Processing Record 3 of the Set 5 | kargil
# Processing Record 4 of the Set 5 | axim
# Processing Record 5 of the Set 5 | kysyl-syr
# Processing Record 6 of the Set 5 | locri
# Processing Record 7 of the Set 5 | durban
# Processing Record 8 of the Set 5 | qaanaaq
# City not found. Skipping...
# Processing Record 9 of the Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 10 of the Set 5 | isla vista
# Processing Record 11 of the Set 5 | hermanus
# Processing Record 12 of the Set 5 | hofn
# Processing Record 13 of the Set 5 | upernavik
# City not found. Skipping...
# Processing Record 14 of the Set 5 | flinders
# Processing Record 15 of the Set 5 | chokurdakh
# Processing Record 16 of the Set 5 | bengkulu
# Processing Record 17 of the Set 5 | ye
# Processing Record 18 of the Set 5 | avarua
# Processing Record 19 of the Set 5 | marcona
# Processing Record 20 of the Set 5 | gorno-chuyskiy
# Processing Record 21 of the Set 5 | airai
# Processing Record 22 of the Set 5 | nanortalik
# City not found. Skipping...
# Processing Record 23 of the Set 5 | cape canaveral
# Processing Record 24 of the Set 5 | cabo san lucas
# Processing Record 25 of the Set 5 | gouyave
# Processing Record 26 of the Set 5 | pinega
# Processing Record 27 of the Set 5 | carnarvon
# Processing Record 28 of the Set 5 | jishou
# Processing Record 29 of the Set 5 | aleksandrovskoye
# Processing Record 30 of the Set 5 | tura
# Processing Record 31 of the Set 5 | bambous virieux
# Processing Record 32 of the Set 5 | nuuk
# City not found. Skipping...
# Processing Record 33 of the Set 5 | phonhong
# Processing Record 34 of the Set 5 | ketchikan
# Processing Record 35 of the Set 5 | dunedin
# Processing Record 36 of the Set 5 | limbang
# Processing Record 37 of the Set 5 | christiana
# Processing Record 38 of the Set 5 | saint george
# Processing Record 39 of the Set 5 | inuvik
# Processing Record 40 of the Set 5 | terre haute
# Processing Record 41 of the Set 5 | pangnirtung
# Processing Record 42 of the Set 5 | lompoc
# Processing Record 43 of the Set 5 | kaeo
# Processing Record 44 of the Set 5 | lappeenranta
# Processing Record 45 of the Set 5 | zhuhai
# Processing Record 46 of the Set 5 | artyom
# Processing Record 47 of the Set 5 | velden am worthersee
# Processing Record 48 of the Set 5 | tak
# Processing Record 49 of the Set 5 | shenjiamen
# Processing Record 50 of the Set 5 | port elizabeth
# Processing Record 1 of the Set 6 | corum
# Processing Record 2 of the Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 3 of the Set 6 | port augusta
# Processing Record 4 of the Set 6 | tasiilaq
# City not found. Skipping...
# Processing Record 5 of the Set 6 | warqla
# City not found. Skipping...
# Processing Record 6 of the Set 6 | ponta do sol
# Processing Record 7 of the Set 6 | nizhneyansk
# Processing Record 8 of the Set 6 | dwarka
# Processing Record 9 of the Set 6 | lambarene
# Processing Record 10 of the Set 6 | ilulissat
# City not found. Skipping...
# Processing Record 11 of the Set 6 | temaraia
# City not found. Skipping...
# Processing Record 12 of the Set 6 | semirom
# Processing Record 13 of the Set 6 | tommot
# Processing Record 14 of the Set 6 | camacha
# Processing Record 15 of the Set 6 | tsabong
# Processing Record 16 of the Set 6 | biltine
# Processing Record 17 of the Set 6 | sertanopolis
# Processing Record 18 of the Set 6 | narsaq
# City not found. Skipping...
# Processing Record 19 of the Set 6 | kytlym
# Processing Record 20 of the Set 6 | nhulunbuy
# Processing Record 21 of the Set 6 | bethel
# Processing Record 22 of the Set 6 | gazli
# City not found. Skipping...
# Processing Record 23 of the Set 6 | mehamn
# Processing Record 24 of the Set 6 | tiksi
# Processing Record 25 of the Set 6 | san cristobal
# Processing Record 26 of the Set 6 | avera
# Processing Record 27 of the Set 6 | los llanos de aridane
# Processing Record 28 of the Set 6 | burnie
# Processing Record 29 of the Set 6 | batagay
# Processing Record 30 of the Set 6 | port lincoln
# Processing Record 31 of the Set 6 | navalmoral de la mata
# Processing Record 32 of the Set 6 | fairbanks
# Processing Record 33 of the Set 6 | sisimiut
# City not found. Skipping...
# Processing Record 34 of the Set 6 | marv dasht
# Processing Record 35 of the Set 6 | quepos
# Processing Record 36 of the Set 6 | okhotsk
# Processing Record 37 of the Set 6 | mehran
# Processing Record 38 of the Set 6 | alto araguaia
# Processing Record 39 of the Set 6 | katsuura
# Processing Record 40 of the Set 6 | balkanabat
# Processing Record 41 of the Set 6 | udachnyy
# Processing Record 42 of the Set 6 | karaul
# Processing Record 43 of the Set 6 | tay ninh
# Processing Record 44 of the Set 6 | burica
# City not found. Skipping...
# Processing Record 45 of the Set 6 | tyukhtet
# Processing Record 46 of the Set 6 | severnyy
# Processing Record 47 of the Set 6 | taoudenni
# Processing Record 48 of the Set 6 | sao joao da barra
# Processing Record 49 of the Set 6 | candolim
# Processing Record 50 of the Set 6 | saldanha
# Processing Record 1 of the Set 7 | saleaula
# City not found. Skipping...
# Processing Record 2 of the Set 7 | vostok
# Processing Record 3 of the Set 7 | pacific grove
# Processing Record 4 of the Set 7 | ntchisi
# Processing Record 5 of the Set 7 | taksimo
# Processing Record 6 of the Set 7 | kashirskoye
# Processing Record 7 of the Set 7 | najran
# Processing Record 8 of the Set 7 | mwinilunga
# Processing Record 9 of the Set 7 | ishigaki
# Processing Record 10 of the Set 7 | reconquista
# Processing Record 11 of the Set 7 | tucumcari
# Processing Record 12 of the Set 7 | acu
# Processing Record 13 of the Set 7 | georgetown
# Processing Record 14 of the Set 7 | qeshm
# Processing Record 15 of the Set 7 | qaqortoq
# City not found. Skipping...
# Processing Record 16 of the Set 7 | mount isa
# Processing Record 17 of the Set 7 | san rafael
# Processing Record 18 of the Set 7 | jalu
# Processing Record 19 of the Set 7 | viligili
# Processing Record 20 of the Set 7 | comodoro rivadavia
# Processing Record 21 of the Set 7 | kimbe
# Processing Record 22 of the Set 7 | hermosillo
# Processing Record 23 of the Set 7 | wicklow
# Processing Record 24 of the Set 7 | havre-saint-pierre
# Processing Record 25 of the Set 7 | dembi dolo
# Processing Record 26 of the Set 7 | gualeguay
# Processing Record 27 of the Set 7 | broken hill
# Processing Record 28 of the Set 7 | lumut
# Processing Record 29 of the Set 7 | bargal
# Processing Record 30 of the Set 7 | beloha
# City not found. Skipping...
# Processing Record 31 of the Set 7 | maibong
# Processing Record 32 of the Set 7 | loukhi
# Processing Record 33 of the Set 7 | tandil
# Processing Record 34 of the Set 7 | coquimbo
# Processing Record 35 of the Set 7 | kununurra
# Processing Record 36 of the Set 7 | sete
# Processing Record 37 of the Set 7 | kamenskoye
# Processing Record 38 of the Set 7 | chicama
# Processing Record 39 of the Set 7 | upington
# Processing Record 40 of the Set 7 | darhan
# Processing Record 41 of the Set 7 | kamenka
# Processing Record 42 of the Set 7 | hauterive
# Processing Record 43 of the Set 7 | banjar
# Processing Record 44 of the Set 7 | los corrales de buelna
# Processing Record 45 of the Set 7 | altamira
# Processing Record 46 of the Set 7 | klaksvik
# Processing Record 47 of the Set 7 | kandrian
# Processing Record 48 of the Set 7 | karpathos
# Processing Record 49 of the Set 7 | batagay-alyta
# Processing Record 50 of the Set 7 | hihifo
# Processing Record 1 of the Set 8 | pak phanang
# Processing Record 2 of the Set 8 | kruglolesskoye
# Processing Record 3 of the Set 8 | kahului
# Processing Record 4 of the Set 8 | sao filipe
# Processing Record 5 of the Set 8 | akola
# Processing Record 6 of the Set 8 | broome
# Processing Record 7 of the Set 8 | asau
# Processing Record 8 of the Set 8 | lavrentiya
# Processing Record 9 of the Set 8 | kudahuvadhoo
# Processing Record 10 of the Set 8 | wagga wagga
# Processing Record 11 of the Set 8 | quzhou
# Processing Record 12 of the Set 8 | fuerte olimpo
# Processing Record 13 of the Set 8 | sioux lookout
# Processing Record 14 of the Set 8 | abeche
# Processing Record 15 of the Set 8 | muravlenko
# Processing Record 16 of the Set 8 | verkhoyansk
# Processing Record 17 of the Set 8 | kaka
# Processing Record 18 of the Set 8 | lamar
# Processing Record 19 of the Set 8 | hanyang
# Processing Record 20 of the Set 8 | rocha
# Processing Record 21 of the Set 8 | lokosovo
# Processing Record 22 of the Set 8 | kabalo
# Processing Record 23 of the Set 8 | luanda
# Processing Record 24 of the Set 8 | weligama
# Processing Record 25 of the Set 8 | touros
# Processing Record 26 of the Set 8 | buta
# Processing Record 27 of the Set 8 | kangaatsiaq
# City not found. Skipping...
# Processing Record 28 of the Set 8 | marzuq
# Processing Record 29 of the Set 8 | sliedrecht
# Processing Record 30 of the Set 8 | knyaze-volkonskoye
# Processing Record 31 of the Set 8 | samusu
# City not found. Skipping...
# Processing Record 32 of the Set 8 | pakxan
# Processing Record 33 of the Set 8 | guerrero negro
# Processing Record 34 of the Set 8 | halalo
# City not found. Skipping...
# Processing Record 35 of the Set 8 | kapenguria
# Processing Record 36 of the Set 8 | hervey bay
# Processing Record 37 of the Set 8 | tuatapere
# Processing Record 38 of the Set 8 | poya
# Processing Record 39 of the Set 8 | khash
# Processing Record 40 of the Set 8 | leander
# Processing Record 41 of the Set 8 | pimenta bueno
# Processing Record 42 of the Set 8 | vestmannaeyjar
# Processing Record 43 of the Set 8 | vondrozo
# City not found. Skipping...
# Processing Record 44 of the Set 8 | longyearbyen
# City not found. Skipping...
# Processing Record 45 of the Set 8 | north branch
# Processing Record 46 of the Set 8 | sitka
# Processing Record 47 of the Set 8 | canguaretama
# Processing Record 48 of the Set 8 | sorland
# Processing Record 49 of the Set 8 | lowestoft
# Processing Record 50 of the Set 8 | samarinda
# Processing Record 1 of the Set 9 | lac du bonnet
# Processing Record 2 of the Set 9 | geresk
# City not found. Skipping...
# Processing Record 3 of the Set 9 | boden
# Processing Record 4 of the Set 9 | tawau
# Processing Record 5 of the Set 9 | liverpool
# Processing Record 6 of the Set 9 | srandakan
# Processing Record 7 of the Set 9 | gornopravdinsk
# Processing Record 8 of the Set 9 | vila
# Processing Record 9 of the Set 9 | plettenberg bay
# Processing Record 10 of the Set 9 | aleksandrovskiy zavod
# Processing Record 11 of the Set 9 | novopokrovka
# Processing Record 12 of the Set 9 | nishihara
# Processing Record 13 of the Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 14 of the Set 9 | hanmer springs
# Processing Record 15 of the Set 9 | bacuit
# Processing Record 16 of the Set 9 | yuanli
# Processing Record 17 of the Set 9 | ruatoria
# Processing Record 18 of the Set 9 | mafinga
# Processing Record 19 of the Set 9 | torbat-e jam
# Processing Record 20 of the Set 9 | sarkand
# Processing Record 21 of the Set 9 | nerchinskiy zavod
# Processing Record 22 of the Set 9 | aragats
# Processing Record 23 of the Set 9 | altay
# Processing Record 24 of the Set 9 | rolim de moura
# Processing Record 25 of the Set 9 | yeniseysk
# Processing Record 26 of the Set 9 | ruhengeri
# Processing Record 27 of the Set 9 | petropavlovsk-kamchatskiy
# Processing Record 28 of the Set 9 | codrington
# Processing Record 29 of the Set 9 | aljezur
# Processing Record 30 of the Set 9 | grindavik
# Processing Record 31 of the Set 9 | falealupo
# City not found. Skipping...
# Processing Record 32 of the Set 9 | kolosovka
# Processing Record 33 of the Set 9 | vanavara
# Processing Record 34 of the Set 9 | mogadishu
# Processing Record 35 of the Set 9 | franklin
# Processing Record 36 of the Set 9 | vao
# Processing Record 37 of the Set 9 | shieli
# Processing Record 38 of the Set 9 | yamada
# Processing Record 39 of the Set 9 | hope
# Processing Record 40 of the Set 9 | quatre cocos
# Processing Record 41 of the Set 9 | lagos
# Processing Record 42 of the Set 9 | zunyi
# Processing Record 43 of the Set 9 | acapulco
# Processing Record 44 of the Set 9 | sayabec
# Processing Record 45 of the Set 9 | umzimvubu
# Processing Record 46 of the Set 9 | zhigansk
# Processing Record 47 of the Set 9 | guarne
# Processing Record 48 of the Set 9 | saint-joseph
# Processing Record 49 of the Set 9 | iralaya
# Processing Record 50 of the Set 9 | grenada
# Processing Record 1 of the Set 10 | namatanai
# Processing Record 2 of the Set 10 | leh
# Processing Record 3 of the Set 10 | moree
# Processing Record 4 of the Set 10 | port hedland
# Processing Record 5 of the Set 10 | akdepe
# Processing Record 6 of the Set 10 | douglas
# Processing Record 7 of the Set 10 | santa maria
# Processing Record 8 of the Set 10 | yuli
# Processing Record 9 of the Set 10 | port macquarie
# Processing Record 10 of the Set 10 | topolobampo
# Processing Record 11 of the Set 10 | woodward
# Processing Record 12 of the Set 10 | kungsbacka
# Processing Record 13 of the Set 10 | bur gabo
# Processing Record 14 of the Set 10 | grand gaube
# Processing Record 15 of the Set 10 | tarakan
# Processing Record 16 of the Set 10 | konevo
# Processing Record 17 of the Set 10 | janauba
# Processing Record 18 of the Set 10 | mwingi
# Processing Record 19 of the Set 10 | kot isa khan
# Processing Record 20 of the Set 10 | souillac
# Processing Record 21 of the Set 10 | te anau
# Processing Record 22 of the Set 10 | macusani
# Processing Record 23 of the Set 10 | irtyshskiy
# Processing Record 24 of the Set 10 | selma
# Processing Record 25 of the Set 10 | hovd
# Processing Record 26 of the Set 10 | kyzyl-suu
# Processing Record 27 of the Set 10 | merauke
# Processing Record 28 of the Set 10 | srednekolymsk
# Processing Record 29 of the Set 10 | puerto quijarro
# Processing Record 30 of the Set 10 | vardo
# Processing Record 31 of the Set 10 | zarubino
# Processing Record 32 of the Set 10 | chutove
# Processing Record 33 of the Set 10 | sorong
# Processing Record 34 of the Set 10 | norfolk
# Processing Record 35 of the Set 10 | saint-augustin
# Processing Record 36 of the Set 10 | bowmore
# Processing Record 37 of the Set 10 | gravdal
# Processing Record 38 of the Set 10 | provideniya
# Processing Record 39 of the Set 10 | ust-maya
# Processing Record 40 of the Set 10 | murzzuschlag
# Processing Record 41 of the Set 10 | auxerre
# Processing Record 42 of the Set 10 | kyela
# Processing Record 43 of the Set 10 | shira
# Processing Record 44 of the Set 10 | mendoza
# Processing Record 45 of the Set 10 | novikovo
# Processing Record 46 of the Set 10 | cayenne
# Processing Record 47 of the Set 10 | creston
# Processing Record 48 of the Set 10 | maghama
# City not found. Skipping...
# Processing Record 49 of the Set 10 | hambantota
# Processing Record 50 of the Set 10 | malakal
# Processing Record 1 of the Set 11 | buraydah
# Processing Record 2 of the Set 11 | tangping
# Processing Record 3 of the Set 11 | richards bay
# Processing Record 4 of the Set 11 | roald
# Processing Record 5 of the Set 11 | fraserburgh
# Processing Record 6 of the Set 11 | zeya
# Processing Record 7 of the Set 11 | lufilufi
# City not found. Skipping...
# Processing Record 8 of the Set 11 | natchez
# Processing Record 9 of the Set 11 | nakamura
# Processing Record 10 of the Set 11 | tumannyy
# Processing Record 11 of the Set 11 | ucluelet
# Processing Record 12 of the Set 11 | charters towers
# Processing Record 13 of the Set 11 | bodden town
# Processing Record 14 of the Set 11 | maneadero
# Processing Record 15 of the Set 11 | joetsu
# Processing Record 16 of the Set 11 | bonthe
# Processing Record 17 of the Set 11 | westport
# Processing Record 18 of the Set 11 | aswan
# Processing Record 19 of the Set 11 | stoyba
# Processing Record 20 of the Set 11 | sobolevo
# Processing Record 21 of the Set 11 | alpharetta
# Processing Record 22 of the Set 11 | orapa
# Processing Record 23 of the Set 11 | kosa
# Processing Record 24 of the Set 11 | bandarbeyla
# Processing Record 25 of the Set 11 | porto walter
# Processing Record 26 of the Set 11 | khani
# Processing Record 27 of the Set 11 | bonavista
# Processing Record 28 of the Set 11 | francistown
# Processing Record 29 of the Set 11 | aykhal
# Processing Record 30 of the Set 11 | mollendo
# Processing Record 31 of the Set 11 | tautira
# Processing Record 32 of the Set 11 | nemuro
# Processing Record 33 of the Set 11 | sokolo
# Processing Record 34 of the Set 11 | tadine
# Processing Record 35 of the Set 11 | bijie
# Processing Record 36 of the Set 11 | zapolyarnyy
# Processing Record 37 of the Set 11 | puerto suarez
# Processing Record 38 of the Set 11 | kruisfontein
# Processing Record 39 of the Set 11 | kaa-khem
# Processing Record 40 of the Set 11 | santa cruz
# Processing Record 41 of the Set 11 | lingyuan
# Processing Record 42 of the Set 11 | porosozero
# Processing Record 43 of the Set 11 | robinson
# Processing Record 44 of the Set 11 | denizli
# Processing Record 45 of the Set 11 | morros
# Processing Record 46 of the Set 11 | biskamzha
# Processing Record 47 of the Set 11 | paita
# Processing Record 48 of the Set 11 | xuddur
# Processing Record 49 of the Set 11 | ngukurr
# Processing Record 50 of the Set 11 | ushtobe
# Processing Record 1 of the Set 12 | omboue
# Processing Record 2 of the Set 12 | havoysund
# Processing Record 3 of the Set 12 | bucerias
# Processing Record 4 of the Set 12 | kajaani
# Processing Record 5 of the Set 12 | miraflores
# Processing Record 6 of the Set 12 | muisne
# Processing Record 7 of the Set 12 | sembakung
# Processing Record 8 of the Set 12 | deputatskiy
# Processing Record 9 of the Set 12 | sola
# Processing Record 10 of the Set 12 | aalen
# Processing Record 11 of the Set 12 | talas
# Processing Record 12 of the Set 12 | mbeya
# Processing Record 13 of the Set 12 | jutai
# Processing Record 14 of the Set 12 | mount gambier
# Processing Record 15 of the Set 12 | rabaul
# Processing Record 16 of the Set 12 | carndonagh
# Processing Record 17 of the Set 12 | shalinskoye
# Processing Record 18 of the Set 12 | onega
# Processing Record 19 of the Set 12 | monterey
# Processing Record 20 of the Set 12 | jinchang
# Processing Record 21 of the Set 12 | edson
# Processing Record 22 of the Set 12 | roma
# Processing Record 23 of the Set 12 | dingle
# Processing Record 24 of the Set 12 | tilaran
# Processing Record 25 of the Set 12 | huarmey
# Processing Record 26 of the Set 12 | gat
# Processing Record 27 of the Set 12 | koryukivka
# Processing Record 28 of the Set 12 | pathardi
# Processing Record 29 of the Set 12 | oeiras
# Processing Record 30 of the Set 12 | baoning
# Processing Record 31 of the Set 12 | salinas
# Processing Record 32 of the Set 12 | lobito
# Processing Record 33 of the Set 12 | eyl
# Processing Record 34 of the Set 12 | salmas
# Processing Record 35 of the Set 12 | mount pleasant
# Processing Record 36 of the Set 12 | kitahiroshima
# Processing Record 37 of the Set 12 | yanan
# Processing Record 38 of the Set 12 | santa luzia
# Processing Record 39 of the Set 12 | college
# Processing Record 40 of the Set 12 | ocean city
# Processing Record 41 of the Set 12 | krasnyy luch
# Processing Record 42 of the Set 12 | road town
# Processing Record 43 of the Set 12 | copiapo
# Processing Record 44 of the Set 12 | alotau
# Processing Record 45 of the Set 12 | ixtapa
# Processing Record 46 of the Set 12 | melfi
# Processing Record 47 of the Set 12 | beinamar
# Processing Record 48 of the Set 12 | kholmogory
# Processing Record 49 of the Set 12 | jeremie
# Processing Record 50 of the Set 12 | wattegama
# Processing Record 1 of the Set 13 | myitkyina
# Processing Record 2 of the Set 13 | lolua
# Processing Record 3 of the Set 13 | rundu
# Processing Record 4 of the Set 13 | loandjili
# Processing Record 5 of the Set 13 | danjiangkou
# Processing Record 6 of the Set 13 | alhaurin el grande
# Processing Record 7 of the Set 13 | gamboula
# Processing Record 8 of the Set 13 | baghdad
# Processing Record 9 of the Set 13 | palauig
# Processing Record 10 of the Set 13 | palu
# Processing Record 11 of the Set 13 | vrangel
# Processing Record 12 of the Set 13 | lesnoy
# Processing Record 13 of the Set 13 | asmara
# Processing Record 14 of the Set 13 | lake havasu city
# Processing Record 15 of the Set 13 | palora
# Processing Record 16 of the Set 13 | ende
# Processing Record 17 of the Set 13 | montemor-o-novo
# Processing Record 18 of the Set 13 | carmelo
# Processing Record 19 of the Set 13 | ochamchira
# Processing Record 20 of the Set 13 | wad rawah
# Processing Record 21 of the Set 13 | strezhevoy
# Processing Record 22 of the Set 13 | byron bay
# Processing Record 23 of the Set 13 | hualmay
# Processing Record 24 of the Set 13 | praia da vitoria
# Processing Record 25 of the Set 13 | belyy yar
# Processing Record 26 of the Set 13 | goure
# Processing Record 27 of the Set 13 | ondorhaan
# Processing Record 28 of the Set 13 | birao
# Processing Record 29 of the Set 13 | berlevag
# Processing Record 30 of the Set 13 | yambio
# Processing Record 31 of the Set 13 | champerico
# Processing Record 32 of the Set 13 | balikpapan
# Processing Record 33 of the Set 13 | berbera
# Processing Record 34 of the Set 13 | kourou
# Processing Record 35 of the Set 13 | khandyga
# Processing Record 36 of the Set 13 | carroll
# Processing Record 37 of the Set 13 | kalabo
# Processing Record 38 of the Set 13 | kitama
# Processing Record 39 of the Set 13 | rawson
# Processing Record 40 of the Set 13 | krasnoselkup
# Processing Record 41 of the Set 13 | goderich
# Processing Record 42 of the Set 13 | lodwar
# Processing Record 43 of the Set 13 | elizabeth city
# Processing Record 44 of the Set 13 | sungurlu
# Processing Record 45 of the Set 13 | mabaruma
# Processing Record 46 of the Set 13 | cravo norte
# Processing Record 47 of the Set 13 | killam
# Processing Record 48 of the Set 13 | severobaykalsk
# Processing Record 49 of the Set 13 | yaring
# Processing Record 50 of the Set 13 | ambilobe
# Processing Record 1 of the Set 14 | kungurtug
# Processing Record 2 of the Set 14 | macia
# Processing Record 3 of the Set 14 | nabire
# Processing Record 4 of the Set 14 | paramonga
# Processing Record 5 of the Set 14 | langxiang
# Processing Record 6 of the Set 14 | verkhnevilyuysk
# Processing Record 7 of the Set 14 | hearst
# Processing Record 8 of the Set 14 | pochutla
# Processing Record 9 of the Set 14 | tsaratanana
# Processing Record 10 of the Set 14 | ada
# Processing Record 11 of the Set 14 | kulhudhuffushi
# Processing Record 12 of the Set 14 | polyarnyy
# Processing Record 13 of the Set 14 | shache
# Processing Record 14 of the Set 14 | kagoro
# Processing Record 15 of the Set 14 | pingzhuang
# Processing Record 16 of the Set 14 | bronzani majdan
# Processing Record 17 of the Set 14 | sovetskiy
# Processing Record 18 of the Set 14 | longlac
# Processing Record 19 of the Set 14 | zalalovo
# Processing Record 20 of the Set 14 | anadyr
# Processing Record 21 of the Set 14 | san pedro
# Processing Record 22 of the Set 14 | san patricio
# Processing Record 23 of the Set 14 | wamba
# Processing Record 24 of the Set 14 | milos
# Processing Record 25 of the Set 14 | vaiano
# Processing Record 26 of the Set 14 | honiara
# Processing Record 27 of the Set 14 | beian
# Processing Record 28 of the Set 14 | porbandar
# Processing Record 29 of the Set 14 | arklow
# Processing Record 30 of the Set 14 | ouahigouya
# Processing Record 31 of the Set 14 | lincoln
# Processing Record 32 of the Set 14 | saint anthony
# Processing Record 33 of the Set 14 | worthing
# Processing Record 34 of the Set 14 | toktogul
# Processing Record 35 of the Set 14 | monte alegre de sergipe
# Processing Record 36 of the Set 14 | labutta
# Processing Record 37 of the Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 38 of the Set 14 | matara
# Processing Record 39 of the Set 14 | cortez
# Processing Record 40 of the Set 14 | mbandaka
# Processing Record 41 of the Set 14 | tarudant
# City not found. Skipping...
# Processing Record 42 of the Set 14 | kokstad
# Processing Record 43 of the Set 14 | maun
# Processing Record 44 of the Set 14 | louisbourg
# Processing Record 45 of the Set 14 | fort wellington
# Processing Record 46 of the Set 14 | dawei
# Processing Record 47 of the Set 14 | mizdah
# Processing Record 48 of the Set 14 | tarauaca
# Processing Record 49 of the Set 14 | novopskov
# Processing Record 50 of the Set 14 | iracoubo
# Processing Record 1 of the Set 15 | kerema
# Processing Record 2 of the Set 15 | olafsvik
# Processing Record 3 of the Set 15 | san ignacio
# Processing Record 4 of the Set 15 | mtwango
# Processing Record 5 of the Set 15 | denpasar
# Processing Record 6 of the Set 15 | hit
# Processing Record 7 of the Set 15 | mao
# Processing Record 8 of the Set 15 | namwala
# Processing Record 9 of the Set 15 | tilichiki
# Processing Record 10 of the Set 15 | salekhard
# Processing Record 11 of the Set 15 | tynda
# Processing Record 12 of the Set 15 | camocim
# Processing Record 13 of the Set 15 | kutum
# Processing Record 14 of the Set 15 | tamworth
# Processing Record 15 of the Set 15 | ambanja
# Processing Record 16 of the Set 15 | viljoenskroon
# Processing Record 17 of the Set 15 | villarrobledo
# Processing Record 18 of the Set 15 | praia
# Processing Record 19 of the Set 15 | guilin
# Processing Record 20 of the Set 15 | abalak
# Processing Record 21 of the Set 15 | sidi bu zayd
# City not found. Skipping...
# Processing Record 22 of the Set 15 | koumra
# Processing Record 23 of the Set 15 | necochea
# Processing Record 24 of the Set 15 | koboldo
# Processing Record 25 of the Set 15 | kazachinskoye
# Processing Record 26 of the Set 15 | sampit
# Processing Record 27 of the Set 15 | brus
# Processing Record 28 of the Set 15 | chuncheng
# Processing Record 29 of the Set 15 | banda aceh
# Processing Record 30 of the Set 15 | haldia
# Processing Record 31 of the Set 15 | osoyoos
# Processing Record 32 of the Set 15 | yangshe
# Processing Record 33 of the Set 15 | matagami
# Processing Record 34 of the Set 15 | russkaya polyana
# Processing Record 35 of the Set 15 | yerbogachen
# Processing Record 36 of the Set 15 | harper
# Processing Record 37 of the Set 15 | yarmouth
# Processing Record 38 of the Set 15 | puerto ayacucho
# Processing Record 39 of the Set 15 | egvekinot
# Processing Record 40 of the Set 15 | medway
# Processing Record 41 of the Set 15 | nairobi
# Processing Record 42 of the Set 15 | ponyri
# Processing Record 43 of the Set 15 | farah
# City not found. Skipping...
# Processing Record 44 of the Set 15 | la palma
# City not found. Skipping...
# Processing Record 45 of the Set 15 | negara
# Processing Record 46 of the Set 15 | chagda
# Processing Record 47 of the Set 15 | baie-saint-paul
# Processing Record 48 of the Set 15 | surt
# Processing Record 49 of the Set 15 | olinda
# Processing Record 50 of the Set 15 | labuhan
# Processing Record 1 of the Set 16 | kassala
# Processing Record 2 of the Set 16 | gold coast
# Processing Record 3 of the Set 16 | tahe
# Processing Record 4 of the Set 16 | ilam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 711

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#       City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kapaa      US  22.0752 -159.3190     59.00        77           1
# 1    Mayna      RU  54.1135   47.6231     -6.23        91         100
# 2  Xucheng      CN  20.3500  110.1288     66.20       100          20
# 3   Bratsk      RU  54.1135   47.6231     -6.23        91         100
# 4   Kodiak      US  22.0752 -159.3190     59.00        77           1
#
#    Wind Speed Current Description
# 0       10.36           clear sky
# 1       13.78     overcast clouds
# 2        2.24          few clouds
# 3       13.78     overcast clouds
# 4       10.36           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
